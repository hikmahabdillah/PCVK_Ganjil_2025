# %% [markdown]
# <a href="https://colab.research.google.com/github/hikmahabdillah/PCVK_Ganjil_2025/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum

# %%
from google.colab import drive

# Acessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/joao_pedro.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/joao_pedro.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK_MW/Images/mandrtll2.tiff',img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))    #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(384, 0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(200, 200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

cv.circle(black_img, center=(100, 100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

cv.circle(black_img, center=(400, 400), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(black_img)

cv.line(black_img, pt1=(0, 0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10, 500), fontFace=font, fontScale=4, color=(255,255,0), thickness=3, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pt5 = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pt5
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pt5], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ## Pertanyaan
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# jawab:
#
# Tanpa matplotlib: gambar ditampilkan langsung menggunakan cv2.imshow() atau cv2_imshow() (pada Google Colab). Warna default pada OpenCV adalah BGR (Blue, Green, Red), sehingga tampilan warna bisa berbeda dari warna aslinya.
#
# Dengan matplotlib: gambar ditampilkan menggunakan plt.imshow(). Matplotlib membaca warna dengan format RGB (Red, Green, Blue) sehingga hasil warna terlihat sesuai aslinya. Selain itu, matplotlib memungkinkan penambahan judul, axis, colormap, dan ukuran figure.
#
# ---
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
#
# jawab:
#
# int16 = ukuran data 16 bit
#
# int32 = ukuran data 32 bit
#
# pengaruh:
# Jika menggunakan int16 atau int32, citra tetap bisa terbentuk, tetapi akan lebih boros memori.
#
# int32 memakan memori lebih besar dibanding int16, sehingga kurang efisien jika hanya untuk membuat black image sederhana.
#
# ---
#
# 3. Apakah kegunaan google.colab.patches import cv2_imshow pada potongan kode berikut?
#
# jawab:
#
# menampilkan citra langsung di output cell Google Colab.
#
# ---
#
# 4. Apakah kegunaan skimage import io pada potongan kode soal nomor 3?
#
# jawab:
#
# kegunaannya adalah menyediakan alternatif untuk load dan display image dengan dukungan format gambar yang lebih luas dibanding OpenCV.

# %% [markdown]
# # TUGAS

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?
#
# Jawab:
#
# Tidak, figsize hanya mengubah ukuran tampilan gambar di layar (visualisasi) bukan ukuran pixel citra aslinya. Pixel image tetap sama.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('/content/drive/MyDrive/PCVK_MM/joao_pedro.jpg')
img_rgb = cv2.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

rb = img_rgb.copy()
rb[:,:,1] = 0

gb = img_rgb.copy()
gb[:,:,0] = 0

plt.subplot(1,2,1)
plt.imshow(rb)
plt.title("Red-Blue")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(gb)
plt.title("Green-Blue")
plt.axis('off')

plt.show()

# %%
# 3. Tampilkan image baris ke 20–115, kolom 25–120!
img_boxes = img_rgb.copy()

crop = img_boxes[20:116, 25:121]
plt.imshow(crop)
plt.title("Crop: baris 20–115, kolom 25–120")
plt.axis('off')
plt.show()

# %%
# 4. Tampilkan image baris ke 5–30, semua kolom, channel Red saja!
red_channel = img[5:31, :, 2]  # channel 2 = Red di OpenCV (BGR)
plt.imshow(red_channel, cmap='Reds')
plt.title("Baris 5–30, Channel Red")
plt.axis('off')
plt.show()

# %%
img_boxes = img_rgb.copy()

# buat 5 kotak random di atas image
for i in range(5):
    pt1 = (np.random.randint(0, img_boxes.shape[1]-100), np.random.randint(0, img_boxes.shape[0]-100))
    pt2 = (pt1[0] + np.random.randint(30,100), pt1[1] + np.random.randint(30,100))
    color = (np.random.randint(0,256), np.random.randint(0,256), np.random.randint(0,256))
    cv2.rectangle(img_boxes, pt1, pt2, color, -1)

plt.imshow(img_boxes)
plt.title("5 Kotak Random di atas img_rgb")
plt.axis('off')
plt.show()

# %%
#Tampilkan image dengan posisi terbalik!
flip_img = cv2.flip(img_rgb, 0)  # 0 = flip vertical
plt.imshow(flip_img)
plt.title("Image Terbalik")
plt.axis('off')
plt.show()

# %%
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda
foto = cv2.imread('/content/drive/MyDrive/PCVK_MM/estevao.jpg')
foto_rgb = cv2.cvtColor(foto, cv2.COLOR_BGR2RGB)

cv2.rectangle(foto_rgb, (475,650), (250,400), (255,0,0), 2)   # rectangle
cv2.circle(foto_rgb, (375,550), 60, (0,255,0), 2)             # circle

plt.imshow(foto_rgb)
plt.title("Rectangle & Circle pada Wajah")
plt.axis('off')
plt.show()

# %%
# 8. Buat rectangle pada bagian sudut bawah kiri channel B
b,g,r = cv2.split(foto_rgb)

# tambahkan rectangle di sudut bawah kiri
cv2.rectangle(b, (0, b.shape[0]-50), (50, b.shape[0]), (255,255,255), -1)

plt.imshow(b, cmap='Blues')
plt.title("Rectangle di Channel B")
plt.axis('off')
plt.show()

# %%
#9. Lengkapi tulisan nama file pada file citra dari soal no.8
cv2.putText(b, "image1.jpg", (10,40),
            cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2)

plt.imshow(b, cmap='Blues')
plt.title("Channel B dengan Tulisan")
plt.axis('off')
plt.show()
